# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # READING THE DATA

# %%
df=pd.read_csv('C:/Users/vikas/OneDrive/Desktop/ml data/Wholesale customers data.csv')
df
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicassen        440 non-null    int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %%
df.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                   count          mean           std   min      25%     50%  \
# Channel           440.0      1.322727      0.468052   1.0     1.00     1.0
# Region            440.0      2.543182      0.774272   1.0     2.00     3.0
# Fresh             440.0  12000.297727  12647.328865   3.0  3127.75  8504.0
# Milk              440.0   5796.265909   7380.377175  55.0  1533.00  3627.0
# Grocery           440.0   7951.277273   9503.162829   3.0  2153.00  4755.5
# Frozen            440.0   3071.931818   4854.673333  25.0   742.25  1526.0
# Detergents_Paper  440.0   2881.493182   4767.854448   3.0   256.75   816.5
# Delicassen        440.0   1524.870455   2820.105937   3.0   408.25   965.5
#
#                        75%       max
# Channel               2.00       2.0
# Region                3.00       3.0
# Fresh             16933.75  112151.0
# Milk               7190.25   73498.0
# Grocery           10655.75   92780.0
# Frozen             3554.25   60869.0
# ...

# %% [markdown]
# # Data Visualization:

# %% [markdown]
# # 1.HEAT MAP

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df.isnull(),yticklabels=False,cmap="viridis")
# Out:
# <AxesSubplot: >

# %%
sns.set_theme("poster")
plt.figure(figsize=(5,5))
sns.heatmap(df.corr(),cmap="viridis")
# Out:
# <AxesSubplot: >

# %% [markdown]
# # 2.barchart

# %%
sns.set_theme("poster")
sns.set_style('darkgrid')
plt.figure(figsize=(10,10))
sns.countplot(data=df,x="Region",hue="Channel",palette="rocket")
# Out:
# <AxesSubplot: xlabel='Region', ylabel='count'>

# %% [markdown]
# # 3. lineplot

# %%
plt.figure(figsize=(15,7))
sns.set_theme("poster")
sns.set_style("darkgrid")
sns.lineplot(data=df,x="Milk",y="Fresh",hue="Channel",palette="coolwarm")
# Out:
# <AxesSubplot: xlabel='Milk', ylabel='Fresh'>

# %% [markdown]
# # 4.pie chart

# %%
newdf=df.iloc[:10]
plt.figure(figsize=(20,7))
sns.set_theme("poster")
sns.set_style("darkgrid")
plt.pie(data=newdf,x="Region",labels='Channel')
plt.legend()
plt.show()

# %% [markdown]
# # 5.scatter plot

# %%
regioncount1=df[df['Region']==1]
regioncount2=df[df["Region"]==2]
regioncount3=df[df["Region"]==3].iloc[0:30]

# %%
plt.figure(figsize=(20,8))
sns.set_style("darkgrid")
plt.scatter(x=regioncount1["Milk"],y=regioncount1["Grocery"],color="red",marker="*",label="region-1")
plt.scatter(x=regioncount2["Milk"],y=regioncount2["Grocery"],color="blue",marker="+",label="region-2")
plt.scatter(x=regioncount3["Milk"],y=regioncount3["Grocery"],color="black",marker="o",label="region-3")
plt.xlabel("Milk")
plt.ylabel("Grocery")
plt.legend()
plt.show()
